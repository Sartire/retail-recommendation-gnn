# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import sys
import pickle

# %%
results = pickle.load(open('results.pkl', 'rb'))

# %%
results.keys()
# Out:
# dict_keys(['hop2_r15', 'hop1_r1', 'hop1_r15', 'hop2_r1'])

# %%
results['hop1_r1']
# Out:
#    epoch    train_loss  train_auc  train_f1  train_acc     test_loss  \
# 0      1  1.764289e+06   0.999756  0.999756   0.999756  8.646519e+10
# 1      2  1.689749e+08   0.995648  0.995650   0.995648  2.234655e+10
# 2      3  2.241893e+08   0.987450  0.982104   0.981907  9.512460e-01
# 3      4  7.847827e-01   0.393904  0.056501   0.493670  7.832459e-01
# 4      5  7.235934e-01   0.459438  0.296552   0.504142  7.433338e-01
# 5      6  7.120036e-01   0.463161  0.286085   0.501001  7.250889e-01
# 6      7  7.091561e-01   0.445125  0.091939   0.493670  7.148277e-01
# 7      8  7.077976e-01   0.420505  0.000000   0.500000  7.090832e-01
# 8      9  7.066238e-01   0.396666  0.000000   0.500000  7.063997e-01
# 9     10  7.058778e-01   0.379037  0.000000   0.500000  7.056792e-01
#
#    test_auc  test_f1  test_acc model
# 0  0.500000      0.0       0.5   PGA
# 1  0.500000      0.0       0.5   PGA
# 2  0.500000      0.0       0.5   PGA
# 3  0.500000      0.0       0.5   PGA
# ...
